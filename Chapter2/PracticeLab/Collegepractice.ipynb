# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots

# %%
college=pd.read_csv('/Users/mussabasif/ISLP/Datasets/College.csv')
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
# index_col=0 means to use the first column as the index
college2=pd.read_csv('/Users/mussabasif/ISLP/Datasets/College.csv', index_col=0)
college3=college.rename({"Unnamed: 0":"College"}, axis=1)
college3=college3.set_index('College')
college
college2
college3
# Now each row has an index. That index is the name of the college.
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college=college3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# If we needed a single column we could use a single bracket, however, since we have multiple columns we need double brackets.
# That would make it a list of columns that we need 
data=college[["Top10perc", "Apps", "Enroll"]]

# %%
pd.plotting.scatter_matrix(data, alpha=0.2);

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
college['Elite']=pd.cut(college['Top10perc'], bins=2, labels=['No', 'Yes'])
college['Elite'].value_counts()
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
fig, axes=plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
college['Apps'].plot.hist(bins=30, ax=axes[0,0])
college['Books'].plot.hist(bins=15, ax=axes[0,1])
college['Enroll'].plot.hist(ax=axes[1,0])
college['PhD'].plot.hist(ax=axes[1,1])
# Out:
# <Axes: ylabel='Frequency'>

# %%
college.info()
college
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %% [markdown]
# # h) exploring data

# %%
# Finding out if the average number of applications is higher for Private or public schools
# divide the dataset into private and public datasets
private_college_application=college[college['Private']=='Yes']
public_college_application=college[college['Private']=='No']
private_college_application
public_college_application
# i dont really need to filter by yes or no for the private column. B/c a box plot would plot a graph for each value in the by= paramter
# Out:
#                                      Private   Apps  Accept  Enroll  \
# College
# Angelo State University                   No   3540    2001    1016
# Appalachian State University              No   7313    4664    1910
# Arizona State University Main campus      No  12809   10308    3761
# Arkansas Tech University                  No   1734    1729     951
# Auburn University-Main Campus             No   7548    6791    3070
# ...                                      ...    ...     ...     ...
# Westfield State College                   No   3100    2150     825
# Westmont College                          No    950     713     351
# Winona State University                   No   3325    2047    1301
# Winthrop University                       No   2320    1805     769
# Worcester State College                   No   2197    1515     543
#
#                                       Top10perc  Top25perc  F.Undergrad  \
# College
# ...

# %%
college.boxplot(column='Apps', by='Private')
# this graphs, proves, that the average number of applications for a publi school is higher. The reading closer to 50k may be an outlier which could be disregarded.
# Out:
# <Axes: title={'center': 'Apps'}, xlabel='Private'>
